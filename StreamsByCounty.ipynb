# %%
import os
import geopandas as gpd
import matplotlib.pyplot as plt

counties_path = r'C:\Users\wklei\OneDrive\Documents\College\GISProjects\PythonScripts\MichiganTroutStreams\Data\Counties'
counties_file = 'Counties__v17a_.shp'
counties_fp = os.path.join(counties_path,counties_file)
counties_shape = gpd.read_file(counties_fp)
counties_shape = counties_shape[['NAME', 'PENINSULA', 'geometry']]
fig, ax = plt.subplots(1,1, figsize=(16.5,16.5))
fig = counties_shape.boundary.plot(ax=ax,color='black')
ax = ax.set_title('Michigan Counties')

# %%
print(counties_shape.crs)
# Out:
# PROJCS["NAD83_Michigan_Oblique_Mercator",GEOGCS["NAD83",DATUM["North_American_Datum_1983",SPHEROID["GRS 1980",6378137,298.257222101,AUTHORITY["EPSG","7019"]],AUTHORITY["EPSG","6269"]],PRIMEM["Greenwich",0],UNIT["Degree",0.0174532925199433],AUTHORITY["EPSG","4269"]],PROJECTION["Hotine_Oblique_Mercator"],PARAMETER["latitude_of_center",45.3091666666667],PARAMETER["longitude_of_center",-86],PARAMETER["azimuth",337.25556],PARAMETER["rectified_grid_angle",337.25556],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",2546731.496],PARAMETER["false_northing",-4354009.816],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]

# %%
print(counties_shape.head(83))
# Out:
#          NAME PENINSULA                                           geometry
# 0      Alcona     lower  POLYGON ((667645.901 446868.019, 667641.436 44...
# 1       Alger     upper  MULTIPOLYGON (((413857.668 636758.280, 413868....
# 2     Allegan     lower  POLYGON ((537450.869 208817.483, 537449.788 20...
# 3      Alpena     lower  MULTIPOLYGON (((709624.982 484964.687, 709650....
# 4      Antrim     lower  MULTIPOLYGON (((590680.331 487368.888, 590689....
# ..        ...       ...                                                ...
# 78    Tuscola     lower  MULTIPOLYGON (((726656.547 312083.219, 726588....
# 79  Van Buren     lower  POLYGON ((481476.119 182422.085, 481476.084 18...
# 80  Washtenaw     lower  POLYGON ((654169.938 177414.937, 654142.763 17...
# 81      Wayne     lower  POLYGON ((702125.562 198872.453, 702086.555 19...
# 82    Wexford     lower  POLYGON ((514124.045 406686.302, 514115.886 40...
#
# [83 rows x 3 columns]

# %%
main_path = r'C:\Users\wklei\OneDrive\Documents\College\GISProjects\PythonScripts\MichiganTroutStreams\Data\Streams\Main'
main_file = 'Trout_and_Salmon_Regulations_Stream_Main_2020.shp'
main_fp = os.path.join(main_path, main_file)
main_shape = gpd.read_file(main_fp)
main_shape = main_shape[['GNIS_Name', 'StreamType', 'geometry']]
fig, ax = plt.subplots(1,1, figsize=(15,15))
fig = main_shape.plot(ax=ax)
ax = ax.set_title('Main')

# %%
print(main_shape.crs)
# Out:
# PROJCS["NAD83_Michigan_Oblique_Mercator",GEOGCS["NAD83",DATUM["North_American_Datum_1983",SPHEROID["GRS 1980",6378137,298.257222101,AUTHORITY["EPSG","7019"]],AUTHORITY["EPSG","6269"]],PRIMEM["Greenwich",0],UNIT["Degree",0.0174532925199433],AUTHORITY["EPSG","4269"]],PROJECTION["Hotine_Oblique_Mercator"],PARAMETER["latitude_of_center",45.3091666666667],PARAMETER["longitude_of_center",-86],PARAMETER["azimuth",337.25556],PARAMETER["rectified_grid_angle",337.25556],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",2546731.496],PARAMETER["false_northing",-4354009.816],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]

# %%
print(main_shape.head())
# Out:
#                    GNIS_Name StreamType  \
# 0                       None     Type 1
# 1            Big Sable River     Type 4
# 2            Big Sable River     Type 4
# 3  South Branch Galien River     Type 4
# 4               Galien River     Type 4
#
#                                             geometry
# 0  LINESTRING Z (468272.005 347526.877 0.000, 468...
# 1  LINESTRING Z (472505.087 394443.899 0.000, 472...
# 2  LINESTRING Z (471844.144 393850.309 0.000, 471...
# 3  LINESTRING Z (443889.992 137684.465 0.000, 443...
# 4  LINESTRING Z (454638.671 146025.584 0.000, 454...

# %%
BTRA_path = r'C:\Users\wklei\OneDrive\Documents\College\GISProjects\PythonScripts\MichiganTroutStreams\Data\Streams\BTRA'
BTRA_file = 'Brook_Trout_Restoration_Areas.shp'
BTRA_fp = os.path.join(BTRA_path, BTRA_file)
BTRA_shape = gpd.read_file(BTRA_fp)
fig, ax = plt.subplots(1,1, figsize=(22,22))
fig = BTRA_shape.plot(ax=ax)
ax = ax.set_title('BTRA')

# %%
print(BTRA_shape.crs)
# Out:
# PROJCS["NAD83_Michigan_Oblique_Mercator",GEOGCS["NAD83",DATUM["North_American_Datum_1983",SPHEROID["GRS 1980",6378137,298.257222101,AUTHORITY["EPSG","7019"]],AUTHORITY["EPSG","6269"]],PRIMEM["Greenwich",0],UNIT["Degree",0.0174532925199433],AUTHORITY["EPSG","4269"]],PROJECTION["Hotine_Oblique_Mercator"],PARAMETER["latitude_of_center",45.3091666666667],PARAMETER["longitude_of_center",-86],PARAMETER["azimuth",337.25556],PARAMETER["rectified_grid_angle",337.25556],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",2546731.496],PARAMETER["false_northing",-4354009.816],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]

# %%
print(BTRA_shape.head())
# Out:
#    FID      ComID       FDate  Resolution   GNIS_ID     GNIS_Name  AreaSqKm  \
# 0    1  116542669  2004-01-09           2  00635281  Portage Lake    34.275
#
#         ReachCode  FType  FCode  Designated StreamType StreamTy_1 Regulation  \
# 0  04020103001212    390  39004           1       BTRA       None       BTRA
#
#         RegTypeDes                                GlobalID     SHAPE_Leng  \
# 0  BTRA Designated  {25239FFA-BB2D-43F4-8985-34478CBBF6E9}  211214.762103
#
#      SHAPE_Area                                           geometry
# 0  5.721639e+07  POLYGON Z ((301589.401 741450.746 0.000, 30155...

# %%
lake_path = r'C:\Users\wklei\OneDrive\Documents\College\GISProjects\PythonScripts\MichiganTroutStreams\Data\Streams\Lake'
lake_file = 'Trout_and_Salmon_Inland_Lake_Regulations_2020.shp'
lake_fp = os.path.join(lake_path, lake_file)
lake_shape = gpd.read_file(lake_fp)
lake_shape = lake_shape[['GNIS_Name', 'Designated', 'Regulation', 'geometry']]
fig, ax = plt.subplots(1,1, figsize=(18,18))
fig = lake_shape.plot(ax=ax)
ax = ax.set_title('Lake')

# %%
print(lake_shape.crs)
# Out:
# PROJCS["NAD83_Michigan_Oblique_Mercator",GEOGCS["NAD83",DATUM["North_American_Datum_1983",SPHEROID["GRS 1980",6378137,298.257222101,AUTHORITY["EPSG","7019"]],AUTHORITY["EPSG","6269"]],PRIMEM["Greenwich",0],UNIT["Degree",0.0174532925199433],AUTHORITY["EPSG","4269"]],PROJECTION["Hotine_Oblique_Mercator"],PARAMETER["latitude_of_center",45.3091666666667],PARAMETER["longitude_of_center",-86],PARAMETER["azimuth",337.25556],PARAMETER["rectified_grid_angle",337.25556],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",2546731.496],PARAMETER["false_northing",-4354009.816],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]

# %%
print(lake_shape.head())
# Out:
#            GNIS_Name  Designated Regulation  \
# 0          Reid Lake         0.0     Type B
# 1   South Hoist Lake         0.0     Type B
# 2  Grand Marais Lake         1.0     Type A
# 3         Sitka Lake         1.0     Type A
# 4   Grand Sable Lake         0.0     Type E
#
#                                             geometry
# 0  POLYGON Z ((683687.121 457039.325 0.000, 68367...
# 1  POLYGON Z ((676327.238 456782.466 0.000, 67629...
# 2  POLYGON Z ((507164.827 678014.600 0.000, 50718...
# 3  POLYGON Z ((504428.290 668997.915 0.000, 50442...
# 4  POLYGON Z ((496018.316 674797.677 0.000, 49601...

# %%
fig, ax = plt.subplots(1,1, figsize=(16.5,16.5))
counties_shape.boundary.plot(ax=ax, color='black')
main_shape.plot(ax=ax)
BTRA_shape.plot(ax=ax)
lake_shape.plot(ax=ax)
ax = ax.set_title('All')

# %%
for idx, row in counties_shape.iterrows():
    
    print('Working on', row['NAME'], '...')
    county_box = row['geometry']
    clipped = gpd.clip(main_shape, county_box)
    
    counties_path = r'C:\Users\wklei\OneDrive\Documents\College\GISProjects\PythonScripts\MichiganTroutStreams\Counties'
    counties_name = row['NAME']
    counties_dir = os.mkdir(os.path.join(counties_path, counties_name))
    
    if clipped.empty == True:
        continue
    
    clipped_path = os.path.join(counties_path,counties_name)
    clipped_name = row['NAME'] + 'Main.shp'
    clipped_fp = os.path.join(clipped_path,clipped_name)
    clipped.to_file(clipped_fp)
# Out:
# Working on Alcona ...
# Working on Alger ...
# Working on Allegan ...
# Working on Alpena ...
# Working on Antrim ...
# Working on Arenac ...
# Working on Baraga ...
# Working on Barry ...
# Working on Bay ...
# Working on Benzie ...
# Working on Berrien ...
# Working on Branch ...
# Working on Calhoun ...
# Working on Cass ...
# Working on Charlevoix ...
# Working on Cheboygan ...
# Working on Chippewa ...
# Working on Clare ...
# Working on Clinton ...
# Working on Crawford ...
# Working on Delta ...
# Working on Dickinson ...
# Working on Eaton ...
# Working on Emmet ...
# Working on Genesee ...
# Working on Gladwin ...
# Working on Gogebic ...
# Working on Grand Traverse ...
# Working on Gratiot ...
# Working on Hillsdale ...
# Working on Houghton ...
# Working on Huron ...
# Working on Ingham ...
# Working on Ionia ...
# Working on Iosco ...
# Working on Iron ...
# Working on Isabella ...
# Working on Jackson ...
# Working on Kalamazoo ...
# Working on Kalkaska ...
# ...

# %%
import pandas as pd
for idx, row in counties_shape.iterrows():
    
    county_path = r'C:\Users\wklei\OneDrive\Documents\College\GISProjects\PythonScripts\MichiganTroutStreams\Counties'
    county_file = row['NAME'] + 'Border.shp'
    county_fp = os.path.join(county_path,row['NAME'],county_file)
    county_border_df = pd.DataFrame(row).transpose()
    county_border_gdf = gpd.GeoDataFrame(county_border_df)
    county_border = county_border_gdf.to_file(county_fp)

# %%
for idx, row in counties_shape.iterrows():
    
    print('Working on', row['NAME'], '...')
    county_box = row['geometry']
    clipped_lakes = gpd.clip(lake_shape, county_box)
    
    if clipped_lakes.empty == True:
        continue
        
    counties_folder_path = r'C:\Users\wklei\OneDrive\Documents\College\GISProjects\PythonScripts\MichiganTroutStreams\Counties'
    individual_county = row['NAME']
    specific_county_folder_path = os.path.join(counties_folder_path,individual_county)
    clipped_lakes_name = row['NAME'] + 'Lakes.shp'
    clipped_lakes_fp = os.path.join(specific_county_folder_path,clipped_lakes_name)
    clipped_lakes.to_file(clipped_lakes_fp)
# Out:
# Working on Alcona ...
# Working on Alger ...
# Working on Allegan ...
# Working on Alpena ...
# Working on Antrim ...
# Working on Arenac ...
# Working on Baraga ...
# Working on Barry ...
# Working on Bay ...
# Working on Benzie ...
# Working on Berrien ...
# Working on Branch ...
# Working on Calhoun ...
# Working on Cass ...
# Working on Charlevoix ...
# Working on Cheboygan ...
# Working on Chippewa ...
# Working on Clare ...
# Working on Clinton ...
# Working on Crawford ...
# Working on Delta ...
# Working on Dickinson ...
# Working on Eaton ...
# Working on Emmet ...
# Working on Genesee ...
# Working on Gladwin ...
# Working on Gogebic ...
# Working on Grand Traverse ...
# Working on Gratiot ...
# Working on Hillsdale ...
# Working on Houghton ...
# Working on Huron ...
# Working on Ingham ...
# Working on Ionia ...
# Working on Iosco ...
# Working on Iron ...
# Working on Isabella ...
# Working on Jackson ...
# Working on Kalamazoo ...
# Working on Kalkaska ...
# ...
