# %%
import os
import geopandas as gpd
import matplotlib.pyplot as plt

outline_path = r'C:\Users\wklei\OneDrive\Documents\College\GISProjects\PythonScripts\MichiganTroutStreams\Counties\Clare'
outline_file = 'ClareBorder.shp'
outline_fp = os.path.join(outline_path,outline_file)
outline_shape = gpd.read_file(outline_fp)

clare_path = r'C:\Users\wklei\OneDrive\Documents\College\GISProjects\PythonScripts\MichiganTroutStreams\Counties\Clare'
clare_file = 'ClareMain.shp'
clare_fp = os.path.join(clare_path, clare_file)
clare_shape = gpd.read_file(clare_fp)

fig, ax = plt.subplots(1,1, figsize=(15,15))
fig = clare_shape.plot(ax=ax)
fig = outline_shape.boundary.plot(ax=ax, color='black')
ax = ax.set_title('Clare County Trout Streams')

# %%
print(clare_shape.crs)
# Out:
# PROJCS["NAD83_Michigan_Oblique_Mercator",GEOGCS["NAD83",DATUM["North_American_Datum_1983",SPHEROID["GRS 1980",6378137,298.257222101,AUTHORITY["EPSG","7019"]],AUTHORITY["EPSG","6269"]],PRIMEM["Greenwich",0],UNIT["Degree",0.0174532925199433],AUTHORITY["EPSG","4269"]],PROJECTION["Hotine_Oblique_Mercator"],PARAMETER["latitude_of_center",45.3091666666667],PARAMETER["longitude_of_center",-86],PARAMETER["azimuth",-22.74444],PARAMETER["rectified_grid_angle",-22.74444],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",2546731.496],PARAMETER["false_northing",-4354009.816],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]

# %%
print(clare_shape.head())
# Out:
#       GNIS_Name StreamType                                           geometry
# 0          None     Type 1  LINESTRING Z (574050.533 393982.372 0.000, 574...
# 1          None     Type 1  LINESTRING Z (574479.484 390938.311 0.000, 574...
# 2          None     Type 1  LINESTRING Z (576062.905 391484.266 0.000, 576...
# 3          None     Type 1  LINESTRING Z (578693.273 399481.710 0.000, 578...
# 4  Whisky Creek     Type 1  LINESTRING Z (575217.517 392739.260 0.000, 575...

# %%
clare_shape['GNIS_Name'].unique()
# Out:
# array([None, 'Whisky Creek', 'Clam River', 'Dishwash Creek',
#        'Cranberry Creek', 'Giss-I-Was Creek',
#        'Middle Branch Tobacco River', 'Five Lakes Creek',
#        'South Branch Tobacco River', 'Spike Horn Creek',
#        'North Branch Tobacco River', 'Jose Creek', 'Howe Creek',
#        'Runyon Creek', 'Overton Creek', 'Beaver Creek',
#        'North Branch Chippewa River', 'Atkinson Creek', 'Benjamin Creek',
#        'Newton Creek', 'Loon Lake Creek', 'Elm Creek', 'Mostellar Creek',
#        'Clear Creek', 'West Branch Cedar River',
#        'Middle Branch Cedar River', 'Cedar River', 'Popple Creek',
#        'Town Line Creek', 'Townline Creek'], dtype=object)
